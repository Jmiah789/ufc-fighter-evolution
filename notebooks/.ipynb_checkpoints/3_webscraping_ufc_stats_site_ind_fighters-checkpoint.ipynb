# %%
import requests
from bs4 import BeautifulSoup  
import pandas as pd
import re
import numpy as np

# %%
website_url = 'http://ufcstats.com/fighter-details/d0f3959b4a9747e6'
response = requests.get(website_url)

response.status_code
# Out:
# 200

# %%
print(type(response))
response.content
# Out:
# <class 'requests.models.Response'>
# ...

# %%
soup = BeautifulSoup(response.content, 'lxml')
print(soup.title)
# Out:
# <title>
#     Stats | UFC
#   </title>

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js ie8 lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
#     Stats | UFC
#   </title>
# <meta content="" name="description"/>
# <meta content="" name="viewport"/>
# <link href="/blocks/main.css?ver=50194" rel="stylesheet"/>
# <script src="/js/vendor/modernizr-2.6.2.min.js"></script>
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ...

# %%
names_records = soup.find_all('span')

# %%
names_records
# Out:
# [<span class="b-content__title-highlight">
#                  Jose Aldo
#
#              </span>,
#  <span class="b-content__title-record">
#                  Record: 31-7-0
#              </span>]

# %%
print(names_records[0].text)
# Out:
#                 Jose Aldo

# %%
print(names_records[1].text)
# Out:
#                 Record: 31-7-0

# %%
bio = soup.find_all('li')

# %%
bio
# Out:
# [<li class="b-head__item">
#  <a class="b-head__menu-link" href="/statistics/events/">
#                EVENTS &amp; FIGHTS
#              </a>
#  </li>,
#  <li class="b-head__item b-head__item_state_current">
#  <a class="b-head__menu-link" href="/statistics/fighters">
#                FIGHTERS
#              </a>
#  </li>,
#  <li class="b-head__item">
#  <a class="b-head__menu-link" href="http://statleaders.ufc.com" target="_blank">
#                STAT LEADERS
#              </a>
#  </li>,
#  <li class="b-list__box-list-item b-list__box-list-item_type_block">
#  <i class="b-list__box-item-title b-list__box-item-title_type_width">
#          Height:
#        </i>
#        5' 7"
#      </li>,
#  <li class="b-list__box-list-item b-list__box-list-item_type_block">
#  <i class="b-list__box-item-title b-list__box-item-title_type_width">
#          Weight:
#        </i>
#        135 lbs.
#      </li>,
#  <li class="b-list__box-list-item b-list__box-list-item_type_block">
# ...

# %%
print(bio[0].text)
# Out:
#               EVENTS & FIGHTS

# %%
bio_1 = []
for d in bio:
    print(d.text)
    bio.append(d.text.strip())
# Out:
#               EVENTS & FIGHTS
#
#
#
#
#               FIGHTERS
#
#
#
#
#               STAT LEADERS
#
#
#
#
#         Height:
#
#       5' 7"
#
#
#
#         Weight:
#
#       135 lbs.
#
#
#
#         Reach:
#
#       70"
#
#
#
#         STANCE:
#
#       Orthodox
#
#
#
#         DOB:
#
#
#         Sep 09, 1986
#
#
#
#
#             SLpM:
#
#
#           3.61
#
#
#
#
#             Str. Acc.:
#
#           46%
#
#
#
#             SApM:
#
#           3.74
#
#
#
#             Str. Def:
#
#           60%
#
#
#
#
#
#
#
#             TD Avg.:
#
#           0.51
#
#
#
#             TD Acc.:
#
#           54%
#
#
#
#             TD Def.:
#
#           90%
#
#
#
#             Sub. Avg.:
#
#           0.2
#
#
#
#                 Events & Fights
#
#
#
#
#                 Fighters
#
#
#
#
#                 Stat Leaders
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %%
# Out:
# 200

# %%
# Out:
# <title>
#     Stats | UFC
#   </title>
